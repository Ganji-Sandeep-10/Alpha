# %%
from langgraph.graph import StateGraph, END
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
import os

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# %%
class RepoState(dict):
    files: list  # [(path, content)]
    file_summaries: dict
    project_summary: str

# %%
def summarize_file(state: RepoState):
    file_summaries = {}
    template = PromptTemplate(
        input_variables=["filename", "code"],
        template="""
        You are analyzing a code file.
        Filename: {filename}
        Code:
        {code}

        Provide a clear summary of what this file does.
        """
    )
    for fname, code in state["files"]:
        summary = llm.predict(template.format(filename=fname, code=code[:5000]))  # truncate long files
        file_summaries[fname] = summary
    state["file_summaries"] = file_summaries
    return state

# %%
def summarize_project(state: RepoState):
    all_summaries = "\n".join(
        f"{fname}: {summary}" for fname, summary in state["file_summaries"].items()
    )
    project_summary = llm.predict(f"""
    Here are the summaries of each file in a project:

    {all_summaries}

    Please generate an overall description of the project:
    - What it does
    - Its architecture
    - Its purpose
    """)
    state["project_summary"] = project_summary
    return state

# %%
# ---------- STEP 4: Graph ----------
graph = StateGraph(RepoState)
graph.add_node("summarize_file", summarize_file)
graph.add_node("summarize_project", summarize_project)

graph.set_entry_point("summarize_file")
graph.add_edge("summarize_file", "summarize_project")
graph.add_edge("summarize_project", END)

app = graph.compile()

# %%
# ---------- STEP 5: Run with cleaned batching ----------
import os

local_dir = "./repo_clone2"  # path where you cloned the repo
repo_files = []

# Collect repo files (skip .git folder and other irrelevant stuff)
for root, _, files in os.walk(local_dir):
    if ".git" in root:  # skip git internals
        continue
    for f in files:
        file_path = os.path.join(root, f)
        try:
            with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
                content = file.read()
            rel_path = os.path.relpath(file_path, local_dir)
            repo_files.append((rel_path, content))
        except Exception as e:
            print(f"Skipping {file_path}: {e}")

print(f"Collected {len(repo_files)} files (excluding .git)")

# Split files by size
small_files = [(name, code) for name, code in repo_files if len(code) < 3000]
large_files = [(name, code) for name, code in repo_files if len(code) >= 3000]

file_summaries = {}

# ---------- Summarize small files one-by-one ----------
for name, code in small_files:
    summary = llm.predict(f"""
    Summarize this file's purpose and role in the project.

    File: {name}
    Code:
    {code}
    """)
    file_summaries[name] = summary.strip()

# ---------- Summarize large files (truncate if too big) ----------
for name, code in large_files:
    summary = llm.predict(f"""
    Summarize this LARGE file's purpose and role in the project.
    Only focus on the main components, functions, or logic.

    File: {name}
    Code:
    {code[:5000]}  # truncate to avoid hitting token limit
    """)
    file_summaries[name] = summary.strip()

# ---------- Global project summary ----------
all_summaries_text = "\n".join(f"{fname}: {summary}" for fname, summary in file_summaries.items())
project_summary = llm.predict(f"""
Here are the file summaries from a code repository:

{all_summaries_text}

Now, provide a **global project summary** that explains:
- What the project is
- Its architecture
- Its purpose
- Main components and how they fit together
""")
# Out:
# Collected 10 files (excluding .git)

# %%
# ---------- Output ----------
print("\n=== Project Summary ===")
print(project_summary)

print("\n=== File Summaries ===")
for f, s in file_summaries.items():
    print(f"\n{f}:\n{s}")
# Out:
# === Project Summary ===
# ## To-Do List Project Summary
#
# This project is a simple **To-Do List web application** built using React. Its purpose is to allow users to create, manage, and track tasks they need to complete. Users can add tasks, mark them as complete, and delete them.
#
# **Architecture:**
#
# The application follows a component-based architecture, typical of React projects. It has a clear separation of concerns between data management (state) and UI rendering. The application uses a unidirectional data flow, where data is passed down from parent components to child components via props, and updates are triggered by events handled in the parent component and passed down to child components via props.
#
# **Main Components and Their Interaction:**
#
# *   **`index.js` (Entry Point):** This file bootstraps the React application. It finds the root DOM element (`<div id="root">`) in `public/index.html` and renders the `App` component within it.
#
# *   **`App.js` (Root Component):** This is the core component of the application.
#     *   It manages the application's state using the `useState` hook, holding an array of `tasks`. Each task is an object with `id`, `name`, and `completed` properties.
#     *   It defines functions (`toggleComplete`, `deleteTask`) to update the task list state. These functions are passed as props to the `Task` component.
#     *   It renders the `Heading` and `Task` components, passing the `tasks` array and the state update functions as props to the `Task` component. It also applies global styles.
#
# *   **`Heading.jsx` (Component):** A simple component that renders the main heading "To-Do List".
#
# *   **`Task.js` (Component):** This component is responsible for displaying the list of tasks.
#     *   It receives the `tasks` array, `onToggleComplete` (function to toggle task completion), and `onDelete` (function to delete a task) as props.
#     *   It iterates through the `tasks` array and renders each task as a list item.
#     *   Each task item includes buttons to toggle completion status and delete the task. Clicking these buttons triggers the `onToggleComplete` and `onDelete` functions, which update the application's state in the `App` component.
#
# *   **`public/index.html` (HTML Template):** This file provides the basic HTML structure of the application, including the root element (`<div id="root">`) where the React application is mounted.
#
# *   **`src/styles.css` (Styles):** This file defines global styles for the application, such as font family and text centering.
#
# **Data Flow:**
#
# 1.  The `App` component holds the task data in its state.
# 2.  The `App` component passes the task data and update functions to the `Task` component as props.
# 3.  The `Task` component renders the task list based on the data it receives.
# 4.  When a user interacts with a task (e.g., clicks "Done" or "Delete"), the `Task` component calls the corresponding update function passed down from the `App` component.
# 5.  The `App` component updates its state, triggering a re-render of the application, including the `Task` component, reflecting the changes in the UI.
#
# **Dependencies and Build Process:**
#
# *   The `package.json` file manages the project's dependencies (React, React DOM, etc.) and defines scripts for development (start, build, test).
# *   `.gitignore` excludes the `node_modules` directory from being tracked by Git, as dependencies are managed via `package.json`.
# *   `.eslintrc.json` configures ESLint to use the TypeScript parser, allowing for linting and code style enforcement in TypeScript files.
#
# **Overall, the project is a functional To-Do List application built with React, demonstrating a component-based architecture, unidirectional data flow, and state management using hooks.** The `App` component acts as the central hub for managing the application's state and orchestrating the interaction between other components. The `Task` component handles the presentation and user interaction for the task list.
#
# === File Summaries ===
#
# .eslintrc.json:
# This `.eslintrc.json` file is a configuration file for ESLint, a JavaScript linter. Its purpose is to define the rules and settings that ESLint will use to analyze and enforce code style and quality in the project.
#
# In this specific case, the file is very simple. It only specifies one setting:
#
# *   `"parser": "@typescript-eslint/parser"`: This tells ESLint to use the `@typescript-eslint/parser` package to parse the code. This parser is specifically designed to understand TypeScript syntax, allowing ESLint to correctly analyze TypeScript code and apply relevant linting rules.
#
# Essentially, this file configures ESLint to work with TypeScript code in the project. It ensures that ESLint can understand the TypeScript syntax and semantics, enabling it to effectively lint and enforce code style rules on the TypeScript files.
#
# .gitignore:
# This `.gitignore` file tells Git to ignore the `node_modules` directory.
#
# **Purpose and Role:**
#
# *   **Exclusion:** It prevents the `node_modules` directory and all its contents from being tracked by Git and included in the repository.
# *   **Dependency Management:** `node_modules` typically contains all the dependencies (libraries and packages) used by a Node.js project. These dependencies are usually installed using a package manager like npm or yarn.
# *   **Repository Size Reduction:**  `node_modules` can be very large, as it contains many files. Ignoring it keeps the repository size smaller and more manageable.
# *   **Build Reproducibility:**  Dependencies should be defined in the `package.json` file. Anyone cloning the repository can then install the dependencies themselves using `npm install` or `yarn install`. This ensures that each developer has the correct dependencies installed for the project.
# *   **Avoid Conflicts:** Including `node_modules` can lead to merge conflicts if different developers have different versions or installations of dependencies.
#
# package.json:
# The `package.json` file is the manifest for this React project. It defines:
#
# *   **Project Metadata:** such as the project's name, version, and description.
# *   **Dependencies:** Lists the required libraries (packages) for the project to run, like `react`, `react-dom`, and `react-scripts`. These are essential for the application's core functionality.
# *   **Development Dependencies:** Specifies packages needed only during development, such as `@types/react`, `@types/react-dom`, `loader-utils`, and `typescript`. These aid in tasks like type checking, code transpilation, and building the application.
# *   **Scripts:** Defines commands (like `start`, `build`, `test`) that can be executed using `npm` or `yarn`. These scripts automate common development tasks.
# *   **Browser Compatibility:**  Specifies the target browsers that the application should support using the `browserslist` field.
#
# In essence, `package.json` manages the project's dependencies, build process, and other critical configuration details, making it a fundamental part of the React project's structure. It tells Node.js (and package managers like npm or yarn) everything needed to set up and run the project.
#
# README.md:
# The `README.md` file is a very basic introductory file for a ToDo-List project created using CodeSandbox.  It primarily serves to:
#
# *   **Identify the project:** It states the project is a "ToDo-List".
# *   **Indicate the creation environment:** It mentions the project was created using CodeSandbox.
#
# Essentially, it's a placeholder `README` that provides minimal information about the project. A more detailed `README` would typically include instructions on how to run the project, its features, technologies used, and potentially contribution guidelines.
#
# public\index.html:
# The `public/index.html` file serves as the main HTML template for a React application. It's the entry point that the browser loads initially. Its primary role is to provide the basic HTML structure for the application, including:
#
# *   **HTML Document Structure:** Defines the basic HTML structure with `<head>` and `<body>` tags.
# *   **Metadata:** Includes metadata like character set, viewport settings for responsiveness, theme color, and links to the `manifest.json` and `favicon.ico` files. The `manifest.json` is used for Progressive Web App (PWA) functionality, allowing the app to be installed on devices.
# *   **JavaScript Requirement:** Displays a `<noscript>` message if JavaScript is disabled, informing the user that JavaScript is required to run the application.
# *   **Root Element:** Contains a `div` element with the ID "root" (`<div id="root"></div>`). This is the crucial element where the React application will be mounted and rendered. All the components will be injected into this div by React.
# *   **Development Instructions:** Provides comments with instructions on how to start the development server and build the application for production.
#
# In essence, `index.html` is the shell that React fills with the application's user interface. It's a static file that gets served by the web server, and React then takes over to dynamically render the content within the `#root` element.
#
# src\App.js:
# `src/App.js` is the main component of the React application. Its primary purpose is to:
#
# 1.  **Serve as the root component:** It's the top-level component that renders the entire application structure.
# 2.  **Manage the application's state:** It uses the `useState` hook to maintain a list of `tasks`. Each task has an `id`, `name`, and `completed` status.
# 3.  **Define functions to update the state:** It defines `toggleComplete` to change the `completed` status of a task and `deleteTask` to remove a task from the list. These functions are passed down to child components.
# 4.  **Render the UI:** It renders the `Heading` component and the `Task` component, passing the `tasks` array and the state update functions as props to the `Task` component.  It also imports and applies the global styles from `./styles.css`.
#
# In essence, `App.js` orchestrates the application's data and UI, acting as the central control point for managing the task list and how it's displayed.
#
# src\index.js:
# The `src/index.js` file is the **entry point** for the React application. Its primary purpose is to:
#
# 1.  **Import necessary modules:** It imports `StrictMode` from React, `createRoot` from `react-dom/client`, and the main `App` component from `./App`.
# 2.  **Find the root DOM element:** It locates the HTML element with the ID "root" in the HTML page (presumably in `public/index.html`). This is where the React application will be rendered.
# 3.  **Create a React root:** It uses `createRoot` to create a React root associated with the "root" DOM element. This is the entry point for React to manage the DOM.
# 4.  **Render the App component:** It renders the `App` component (wrapped in `StrictMode` for development-time checks) into the root DOM element. This is what actually starts the React application and displays its content in the browser.
#
# In essence, this file bootstraps the React application by mounting the main `App` component into the DOM. It's the starting point that connects the React code to the HTML structure of the page.
#
# src\styles.css:
# The `src/styles.css` file is the main CSS file for the project. It defines global styles for the application, specifically setting the font family to "sans-serif" and centering the text within the `App` component. It's responsible for the basic visual presentation of the application.
#
# src\components\Heading.jsx:
# The file `src\components\Heading.jsx` defines a simple React component called `Heading`. Its purpose is to render the main heading "To-Do List" within a `div` element. This component likely serves as the primary title or header for the application's user interface. It plays a role in providing a clear and concise label for the application's functionality.
#
# src\components\Task.js:
# The `src\components\Task.js` file defines a React component named `Task`. This component is responsible for rendering a list of tasks and providing interactive elements for each task.
#
# Here's a breakdown of its purpose and role:
#
# *   **Purpose:** To display a list of tasks and allow users to interact with them (mark as complete/incomplete, delete).
# *   **Role:**
#     *   **Rendering:** It receives an array of `tasks` as a prop and uses the `map` function to iterate over them, rendering each task as a list item (`<li>`).
#     *   **State Management (indirectly):** It doesn't manage the task data itself but relies on props passed down from a parent component. It receives:
#         *   `tasks`: The array of task objects to display.
#         *   `onToggleComplete`: A function to call when a task's completion status needs to be toggled (likely updates the state in the parent component).
#         *   `onDelete`: A function to call when a task needs to be deleted (likely updates the state in the parent component).
#     *   **User Interaction:** It provides buttons for toggling the completion status ("Done"/"Undo") and deleting tasks.  Clicking these buttons triggers the `onToggleComplete` and `onDelete` functions passed as props, allowing the parent component to update the application's state.
#     *   **Visual Representation:** It visually represents the task's completion status using CSS (`text-decoration: line-through` for completed tasks).
#
# In essence, `Task.js` is a **presentational component** (also known as a "dumb" or "UI" component) that focuses on *how* the tasks are displayed and interacted with, while relying on its parent component to handle the actual data management and state updates.

# %%
#output generated for 2 files
print("Project Summary:")
print(result["project_summary"])
print("\nFile Summaries:")
for f, s in result["file_summaries"].items():
    print(f"\n{f}:\n{s}")
# Out:
# Project Summary:
# ## Project Description: A Simple To-Do List Application
#
# This project is a basic to-do list application built using React. It allows users to view a list of tasks, mark them as complete or incomplete, and delete them.
#
# **What it does:**
#
# The application provides the following functionality:
#
# *   **Displays a list of tasks:** Each task shows its name and completion status.
# *   **Toggles task completion:** Users can mark tasks as complete or incomplete with a button. Completed tasks are visually distinguished (likely with a strikethrough).
# *   **Deletes tasks:** Users can remove tasks from the list.
#
# **Architecture:**
#
# The application follows a component-based architecture, a common pattern in React development:
#
# *   **`App` Component (./public/index.html):** This is the main component and serves as the root of the application. It:
#     *   Manages the application's state, specifically the list of tasks.
#     *   Provides functions to update the state: `toggleComplete` and `deleteTask`.
#     *   Renders the overall structure and passes data and functions to child components.
# *   **`Task` Component (./src/index.js):** This component is responsible for rendering the list of tasks. It:
#     *   Receives the `tasks` array, `onToggleComplete` function, and `onDelete` function as props from the `App` component.
#     *   Iterates through the `tasks` array and renders each task as a list item.
#     *   Provides buttons for toggling completion status and deleting tasks, calling the appropriate functions passed as props.
# *   **`Heading` Component (./components/Heading):** This component (details not fully provided) is likely a simple component responsible for rendering the title of the application.
# *   **Styling (./styles.css):**  CSS styles are imported to enhance the visual appearance of the application.
#
# The `App` component acts as a container and orchestrator, holding the application's state and passing down relevant data and functions to the `Task` component for rendering and user interaction. This separation of concerns makes the application more modular and maintainable. The use of `useState` hook ensures that the UI is updated whenever the state changes.
#
# **Purpose:**
#
# The purpose of this project is to demonstrate a simple React application that manages a list of items. It showcases fundamental React concepts, including:
#
# *   Component-based architecture
# *   State management using `useState`
# *   Props for passing data and functions between components
# *   Event handling (button clicks)
# *   Rendering lists of data
# *   Functional state updates
#
# It serves as a basic example for learning and understanding how to build interactive web applications with React.
#
# File Summaries:
#
# src/index.js:
# The file `src/index.js` defines a React component called `Task`. This component is responsible for rendering a list of tasks. Each task in the list is displayed with:
#
# 1.  A button to toggle its completion status (labeled "Done" or "Undo" based on the current status). Clicking this button calls the `onToggleComplete` function, passing the task's ID.
# 2.  The task's name, with a line-through style applied if the task is completed.
# 3.  A "Delete" button that, when clicked, calls the `onDelete` function, passing the task's ID.
#
# The component receives three props:
#
# *   `tasks`: An array of task objects, where each object has at least an `id`, `name`, and `completed` property.
# *   `onToggleComplete`: A function to be called when the "Done/Undo" button is clicked.
# *   `onDelete`: A function to be called when the "Delete" button is clicked.
#
# The component iterates through the `tasks` array using `map()` and renders each task as a list item (`<li>`).  The `key` prop is set to `task.id` for efficient React updates.
#
# public/index.html:
# The file `public/index.html` (though it's actually a JavaScript/JSX file for a React component, not a static HTML file) defines the main `App` component of a React application. This component manages a list of tasks, each with an ID, name, and completion status.
#
# Here's a breakdown:
#
# 1.  **Imports:** It imports necessary modules and components:
#     *   `./styles.css`:  Imports CSS styles for the application.
#     *   `./components/Heading`: Imports a `Heading` component (presumably for the title of the app).
#     *   `./components/Task`: Imports a `Task` component which is responsible for displaying and handling the list of tasks.
#     *   `useState` from `react`:  Imports the `useState` hook for managing component state.
#
# 2.  **`App` Component:**
#     *   **State Management:** Uses `useState` to initialize and manage an array of `tasks`. Each task is an object with `id`, `name`, and `completed` properties.  The initial state contains three example tasks.
#     *   **`toggleComplete` Function:** This function takes a task `id` as input. It updates the `tasks` state by finding the task with the matching `id` and toggling its `completed` status.  It uses the functional update form of `setTasks` for correct state updates based on the previous state.
#     *   **`deleteTask` Function:** This function takes a task `id` as input. It updates the `tasks` state by filtering the array to remove the task with the matching `id`. It also uses the functional update form of `setTasks`.
#     *   **JSX Rendering:**  The `return` statement renders the following:
#         *   A `div` with the class name "App" (likely used for overall styling).
#         *   The `Heading` component.
#         *   The `Task` component, passing the `tasks` array, the `toggleComplete` function (as `onToggleComplete`), and the `deleteTask` function (as `onDelete`) as props. This allows the `Task` component to display the tasks, handle completion toggling, and handle deletion of tasks.
#
# In essence, this file sets up the core structure and logic for a simple to-do list application. It manages the task data and passes it down to child components for rendering and interaction.
